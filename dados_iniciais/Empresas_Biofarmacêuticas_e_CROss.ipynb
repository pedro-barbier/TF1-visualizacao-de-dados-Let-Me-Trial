# %% [markdown]
# Bibliotecas importantes

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Tratamento para "Empresas_Biofarmacêuticas_e_CROs.xlsx"

# %% [markdown]
# Entendimento inicial

# %%
# Leitura dos dados
path = "Empresas_Biofarmacêuticas_e_CROs.xlsx"
df_empresas_biofarmaceuticas_e_cros = pd.read_excel(path)
df_empresas_biofarmaceuticas_e_cros_novo = df_empresas_biofarmaceuticas_e_cros.copy()

# %%
print("Formato do dataset:", df_empresas_biofarmaceuticas_e_cros.shape)
print("\nColunas disponíveis:\n", df_empresas_biofarmaceuticas_e_cros.columns.tolist())
print("\nTipos de dados:\n", df_empresas_biofarmaceuticas_e_cros.dtypes)
print("\nValores ausentes:\n", df_empresas_biofarmaceuticas_e_cros.isna().sum())
# Out:
# Formato do dataset: (112, 67)
#
# Colunas disponíveis:
# ...

# %%
# Pequena amostra dos dados
df_empresas_biofarmaceuticas_e_cros.head()
# Out:
#                                         Razão Social  \
# 0                 Abbott Laboratórios Do Brasil Ltda
# 1                           AbbVie Farmacêutica Ltda
# 2               Aché Laboratórios Farmacêuticos S/A.
# 3  Activa-Cro do Brasil Servicos de Pesquisa Clin...
# 4                                     Advance Pharma
#
#                                       Nome Fantasia  \
# 0                                     Abbott Brasil
# 1  AbbVie (divisão Aesthetics: Allergan Aesthetics)
# 2                                              Aché
# 3                                        ACTIVA‑CRO
# 4                                    Advance Pharma
#
#                                   Tier            Tier Prospecção Estado  \
# 0                Tier 3 - Complementar   Tier 1 (alta prioridade)     SP
# 1             Tier 1 - Biofarma Global   Tier 1 (Alta prioridade)     SP
# 2  Tier 2 - Biofarma Nacional/Regional  Tier 2 (Média prioridade)     SP
# ...

# %% [markdown]
# Tratamento

# %%
df_empresas_biofarmaceuticas_e_cros_novo.to_csv('../dados_tratados/Empresas_Biofarmacêuticas_e_CROs_tratado.csv', index=False)
